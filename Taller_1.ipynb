# %% [markdown]
# **TALLER #1**

# %%
Identificacion = input("digite nro de identificacion: ") 
nombre = "Alejandro"
print(nombre)
apellido = "Morales"
print(apellido)
direccion = "Cll 68 93-00"
print(direccion)
telefono = 2241493
print(telefono)
edad = 37
print(edad)
estado_civil = "soltero"
print(estado_civil)
nro_de_hijos = 1
print(nro_de_hijos)
estatura_en_centimetros = 170
print(estatura_en_centimetros)
dia_de_contratacion = "01"
mes_de_contratacion = "03"
año_de_contratacion = "2022"
print(dia_de_contratacion + "/" + mes_de_contratacion + "/" + año_de_contratacion)
sueldo_basico = 3000000
print(sueldo_basico)
dias_laborados = 360
print(dias_laborados)
# Out:
# digite nro de identificacion: 2
# Alejandro
# Morales
# Cll 68 93-00
# 2241493
# 37
# soltero
# 1
# 170
# 01/03/2022
# 3000000
# 360
